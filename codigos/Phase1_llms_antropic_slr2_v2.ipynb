# %% [markdown]
# ### Estudo das respostas de outros modelos de llms - Antropic SLR2

# %% [markdown]
# Vamos simular as variabilidade das respostas das llms, olhando para as soluções da Antropic

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import anthropic
import numpy as np
import time
import os
from dotenv import load_dotenv, find_dotenv
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
### style de execução
tqdm.pandas()

# %% [markdown]
# ### variaveis de ambiente e conexões

# %%
# Carrega as variáveis do arquivo .env
load_dotenv("/data/codigos/.env")
# Out:
# True

# %%
for key in os.environ.keys():
    print(f'{key}')
# Out:
# HOSTNAME
# HOME
# GPG_KEY
# PYTHON_SHA256
# PATH
# LANG
# SHELL
# PYTHON_VERSION
# PWD
# VSCODE_CWD
# VSCODE_NLS_CONFIG
# VSCODE_HANDLES_SIGPIPE
# VSCODE_ESM_ENTRYPOINT
# VSCODE_HANDLES_UNCAUGHT_ERRORS
# REMOTE_CONTAINERS_IPC
# REMOTE_CONTAINERS_SOCKETS
# SHLVL
# _
# REMOTE_CONTAINERS
# BROWSER
# ELECTRON_RUN_AS_NODE
# VSCODE_IPC_HOOK_CLI
# APPLICATION_INSIGHTS_NO_STATSBEAT
# VSCODE_L10N_BUNDLE_LOCATION
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING
# PYTHONUNBUFFERED
# PYTHONIOENCODING
# PYTHON_FROZEN_MODULES
# PYDEVD_USE_FRAME_EVAL
# TERM
# CLICOLOR
# FORCE_COLOR
# CLICOLOR_FORCE
# PAGER
# GIT_PAGER
# MPLBACKEND
# KMP_DUPLICATE_LIB_OK
# KMP_INIT_AT_FORK
# OPENAI_API_KEY_GOV_ANALITICA
# GOOGLE_API_KEY_LLMS_PROF_DANILO
# ANTROPIC_API_KEY_LLMS
# TOGETHER_API_KEY_LLMS
# GOOGLE_CLOUD_PROJECT
# GOOGLE_CLOUD_REGION

# %%
# Configurar a chave de API
client = anthropic.Anthropic(api_key=os.getenv("ANTROPIC_API_KEY_LLMS"))

# %%
# Define os parâmetros da solicitação usando a API de mensagens (v2)
response = client.messages.create(
    model="claude-3-5-haiku-20241022",
    max_tokens=10,
    messages=[
        {"role": "user", "content": "Olá, Claude! Qual a capital do Brasil?"}
    ]
)

# Exibe a resposta gerada pelo mode
print(response.content[0].text)

# %% [markdown]
# # LLMs da Antropic
# -----

# %% [markdown]
# ### Leitura dos arquivos

# %%
df_slr2 = pd.read_excel("/data/codigos/dados/titulo_resumo_palavras_slr2_v2.xlsx",engine='openpyxl')
df_slr2.head()
# Out:
#        ID                                              Title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
# 2  slr2_3  Field guide to gamification: Game components a...
# 3  slr2_4  Gamification of eHealth interventions to incre...
# 4  slr2_5  The relationship between gender and game dynam...
#
#                                               resumo  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
# 2  Although digital and analogue games differ in ...
# 3  Approximately one in five people in the United...
# 4  Despite relatively equal participation rate be...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
# 2  gamification, mechanical engineering, higher e...                 sucesso
# 3  eHealth, gamification, mental health, user eng...                 sucesso
# 4  gender differences, competition, achievement, ...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
# 2                   sucesso            não  não estruturado       sim
# 3                   sucesso            não  não estruturado       sim
# 4                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df_slr2 = df_slr2.replace({r'_x000D_|\n': ''}, regex=True)

# %%
df_slr2.head()
# Out:
#        ID                                              Title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
# 2  slr2_3  Field guide to gamification: Game components a...
# 3  slr2_4  Gamification of eHealth interventions to incre...
# 4  slr2_5  The relationship between gender and game dynam...
#
#                                               resumo  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
# 2  Although digital and analogue games differ in ...
# 3  Approximately one in five people in the United...
# 4  Despite relatively equal participation rate be...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
# 2  gamification, mechanical engineering, higher e...                 sucesso
# 3  eHealth, gamification, mental health, user eng...                 sucesso
# 4  gender differences, competition, achievement, ...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
# 2                   sucesso            não  não estruturado       sim
# 3                   sucesso            não  não estruturado       sim
# 4                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# #### Limpeza dos casos em que não conseguimos extrair as informações

# %%
# aqui precisamos, para reproduzir o artigo que ambos os campos tenho informação
df_slr2_clear = df_slr2.loc[((df_slr2['sucesso_fracasso_resumo'].isin(['sucesso']))&(df_slr2['sucesso_fracasso_palavras'].isin(['sucesso'])))].copy()
df_slr2_clear.shape
# Out:
# (392, 10)

# %%
print("Shape antes da limpeza: "+str(df_slr2.shape))
print("Shape depois da limpeza"+str(df_slr2_clear.shape))
# Out:
# Shape antes da limpeza: (448, 10)
# Shape depois da limpeza(392, 10)

# %%
# Renomear as colunas do dataframe df_slr1_clear
df_slr2_clear.rename(columns={"Title": "title", "resumo": "abstract"}, inplace=True)
df_slr2_clear.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn
# 0            NaN
# 1            NaN

# %% [markdown]
# ### Seleção usando o Antropic

# %%
def process_selection_with_anthropic(model_anthropic, title, abstract, keywords, inclusion_criteria_question):
    """
    Realiza a seleção dos artigos usando a escala Likert com o modelo da Anthropic.
    """
    
    # Construção do prompt
    prompt = f"""
    Assume you are a software engineering researcher conducting a systematic literature review (SLR).
    Considerando o título, resumo e palavras-chave de um estudo primário.

    Usando uma escala Likert de 1 a 7 (1 - Discordo totalmente, 2 - Discordo, 3 - Discordo parcialmente,
    4 - Neutro, 5 - Concordo parcialmente, 6 - Concordo, e 7 - Concordo totalmente), avalie sua concordância 
    com a seguinte pergunta:  

    "{inclusion_criteria_question}"

    Sobre o artigo:  
    **Título:** {title}  
    **Resumo:** {abstract}  
    **Palavras-chave:** {keywords}

    Apenas retorne um número de 1 a 7, sem nenhuma explicação adicional.
    """

    # Fazer a chamada à API da Anthropic
    response = client.messages.create(
        model=model_anthropic,
        max_tokens=1,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    try:
        resposta = int(response.content[0].text.strip())  # Converte a resposta para número inteiro
        return resposta
    except ValueError:
        print("Erro ao processar a resposta:", response.content[0].text)
        return None

# %%
def process_selection_with_anthropic(model_anthropic, title, abstract, keywords, inclusion_criteria_question):
    """
    Realiza a seleção dos artigos usando a escala Likert com o modelo da Anthropic.
    """
    
    # Construção do prompt
    prompt = f"""
    Assume you are a software engineering researcher conducting a systematic literature review (SLR).
    Considering the title, abstract, and keywords of a primary study.

    Using a Likert scale from 1 to 7 (1 - Strongly disagree, 2 - Disagree, 3 - Somewhat disagree,
    4 - Neutral, 5 - Somewhat agree, 6 - Agree, and 7 - Strongly agree), rate your agreement 
    with the following question:  

    "{inclusion_criteria_question}"

    About the article:  
    **Title:** {title}  
    **Abstract:** {abstract}  
    **Keywords:** {keywords}

    Only return a number from 1 to 7, without any additional explanation.
    """

    # Fazer a chamada à API da Anthropic
    response = client.messages.create(
        model=model_anthropic,
        max_tokens=10,
        temperature=0,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    try:
        resposta = int(response.content[0].text.strip())  # Converte a resposta para número inteiro
        return resposta
    except ValueError:
        print("Erro ao processar a resposta:", response.content[0].text)
        return None

# %%
model_anthropic = "claude-3-haiku-20240307" #
title = df_slr1_clear["title"].iloc[0]
abstract = df_slr1_clear["abstract"].iloc[0]
keywords = df_slr1_clear["keywords"].iloc[0]
inclusion_criteria_question = "It is a secondary study (Systematic Review, Mapping Study, Rapid Review, or Systematic Mapping)?"

# %%
resposta_teste = process_selection_with_anthropic(model_anthropic = model_anthropic,
                                            title = title,
                                            abstract = abstract,
                                            keywords = keywords,
                                            inclusion_criteria_question= inclusion_criteria_question)
resposta_teste

# %%
def repeat_selection_with_antropic(df, model_anthropic, inclusion_criteria_question,n_interactions,name_ic):
    """
    Repete o processo de seleção para todos os registros do dataframe
    """
    for i in range(n_interactions):
        coluna_aux = model_anthropic+"_"+name_ic+"_"+str(i)
        temp_filename = f"/data/codigos/dados/resultados/temps/temp_{model_anthropic}_{name_ic}_iter_{i}_v2.xlsx"
        df[coluna_aux] = df.progress_apply(lambda row: process_selection_with_anthropic(model_anthropic,
                                                                                    row['title'],
                                                                                    row['abstract'],
                                                                                    row['keywords'],
                                                                                    inclusion_criteria_question), axis=1)
        # salvando para nao perder
        df.to_excel(temp_filename, index=False)
        time.sleep(15)  # Aguarda 60 segundos entre as chamadas para evitar exceder o limite de uso da API
    return df

# %%
# paramentros globais
n_interactions = 5  # fixemos em 10 vezes devido ao custo

# %% [markdown]
# #### Modelo: "claude-3-haiku-20240307"

# %%
df_claude_haiku_3  = df_slr2_clear.copy()
df_claude_haiku_3.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn
# 0            NaN
# 1            NaN

# %%
# repetir o mesmo processamento n vezes
model_anthropic = "claude-3-haiku-20240307" 
inclusion_criteria_question = """The article discusses the relationship between game
 elements and user types."""
name_ic = "IC1"
df_claude_haiku_3 = repeat_selection_with_antropic(df = df_claude_haiku_3,
                                                    model_anthropic = model_anthropic,
                                                    inclusion_criteria_question = inclusion_criteria_question,
                                                    n_interactions = n_interactions,
                                                    name_ic = name_ic)
# Out:
# 100%|██████████| 392/392 [02:38<00:00,  2.48it/s]
# 100%|██████████| 392/392 [02:40<00:00,  2.45it/s]
# 100%|██████████| 392/392 [02:45<00:00,  2.37it/s]
# 100%|██████████| 392/392 [02:44<00:00,  2.38it/s]
# 100%|██████████| 392/392 [02:42<00:00,  2.42it/s]

# %%
time.sleep(120)

# %%
# repetir o mesmo processamento n vezes
model_anthropic = "claude-3-haiku-20240307" 
inclusion_criteria_question =""" Thearticle discusses how to use the relationship be
tween game elements and user types to analyze user  engagement."""
name_ic = "IC2"
df_claude_haiku_3 = repeat_selection_with_antropic(df = df_claude_haiku_3,
                                                model_anthropic = model_anthropic,
                                                inclusion_criteria_question = inclusion_criteria_question,
                                                n_interactions = n_interactions,
                                                name_ic = name_ic)
# Out:
# 100%|██████████| 392/392 [02:41<00:00,  2.42it/s]
# 100%|██████████| 392/392 [02:39<00:00,  2.45it/s]
# 100%|██████████| 392/392 [02:44<00:00,  2.39it/s]
# 100%|██████████| 392/392 [02:42<00:00,  2.42it/s]
# 100%|██████████| 392/392 [02:46<00:00,  2.35it/s]

# %%
df_claude_haiku_3.head()
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
# 2  slr2_3  Field guide to gamification: Game components a...
# 3  slr2_4  Gamification of eHealth interventions to incre...
# 4  slr2_5  The relationship between gender and game dynam...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
# 2  Although digital and analogue games differ in ...
# 3  Approximately one in five people in the United...
# 4  Despite relatively equal participation rate be...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
# 2  gamification, mechanical engineering, higher e...                 sucesso
# 3  eHealth, gamification, mental health, user eng...                 sucesso
# 4  gender differences, competition, achievement, ...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
# 2                   sucesso            não  não estruturado       sim
# 3                   sucesso            não  não estruturado       sim
# 4                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-haiku-20240307_IC1_0  \
# 0            NaN                              5
# 1            NaN                              5
# 2            NaN                              6
# 3            NaN                              2
# 4            NaN                              6
#
#    claude-3-haiku-20240307_IC1_1  claude-3-haiku-20240307_IC1_2  \
# 0                              5                              5
# 1                              6                              5
# 2                              6                              6
# 3                              2                              2
# 4                              6                              6
#
#    claude-3-haiku-20240307_IC1_3  claude-3-haiku-20240307_IC1_4  \
# 0                              5                              5
# 1                              5                              5
# 2                              6                              6
# 3                              2                              2
# 4                              6                              6
#
#    claude-3-haiku-20240307_IC2_0  claude-3-haiku-20240307_IC2_1  \
# 0                              6                              6
# 1                              5                              5
# 2                              6                              6
# 3                              6                              5
# 4                              6                              6
#
#    claude-3-haiku-20240307_IC2_2  claude-3-haiku-20240307_IC2_3  \
# 0                              6                              6
# 1                              5                              5
# 2                              6                              6
# 3                              5                              5
# 4                              6                              6
#
#    claude-3-haiku-20240307_IC2_4
# 0                              6
# 1                              5
# 2                              6
# 3                              5
# 4                              6

# %% [markdown]
# #### Modelo "claude-3-5-haiku-20241022"

# %%
df_claude_haiku_35  = df_slr2_clear.copy()
df_claude_haiku_35.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn
# 0            NaN
# 1            NaN

# %%
# repetir o mesmo processamento n vezes
model_anthropic = "claude-3-5-haiku-20241022"
inclusion_criteria_question = """the article discusses the relationship between game
 elements and user types."""
name_ic = "IC1"
df_claude_haiku_35 = repeat_selection_with_antropic(df = df_claude_haiku_35,
                                        model_anthropic = model_anthropic,
                                        inclusion_criteria_question = inclusion_criteria_question,
                                        n_interactions = n_interactions,
                                        name_ic = name_ic)
# Out:
# 100%|██████████| 392/392 [05:13<00:00,  1.25it/s]
# 100%|██████████| 392/392 [05:09<00:00,  1.27it/s]
# 100%|██████████| 392/392 [05:16<00:00,  1.24it/s]
# 100%|██████████| 392/392 [05:40<00:00,  1.15it/s]
# 100%|██████████| 392/392 [05:21<00:00,  1.22it/s]

# %%
time.sleep(120)

# %%
# repetir o mesmo processamento n vezes
model_anthropic = "claude-3-5-haiku-20241022"
inclusion_criteria_question =""" Thearticle discusses how to use the relationship be
tween game elements and user types to analyze user  engagement. """
name_ic = "IC2"
df_claude_haiku_35 = repeat_selection_with_antropic(df = df_claude_haiku_35,
                                        model_anthropic = model_anthropic,
                                        inclusion_criteria_question = inclusion_criteria_question,
                                        n_interactions = n_interactions,
                                        name_ic = name_ic)
# Out:
# 100%|██████████| 392/392 [05:06<00:00,  1.28it/s]
# 100%|██████████| 392/392 [05:27<00:00,  1.20it/s]
# 100%|██████████| 392/392 [04:56<00:00,  1.32it/s]
# 100%|██████████| 392/392 [05:05<00:00,  1.28it/s]
# 100%|██████████| 392/392 [05:03<00:00,  1.29it/s]

# %% [markdown]
# ### claude-3-5-sonnet-20241022

# %%
df_claude_sonnet_35  = df_slr2_clear.copy()
df_claude_sonnet_35.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn
# 0            NaN
# 1            NaN

# %%
# repetir o mesmo processamento n vezes
model_anthropic = "claude-3-5-sonnet-20241022"
inclusion_criteria_question = """he article discusses the relationship between game
 elements and user types."""
name_ic = "IC1"
df_claude_sonnet_35 = repeat_selection_with_antropic(df = df_claude_sonnet_35,
                                        model_anthropic = model_anthropic,
                                        inclusion_criteria_question = inclusion_criteria_question,
                                        n_interactions = n_interactions,
                                        name_ic = name_ic)
# Out:
# 100%|██████████| 392/392 [05:10<00:00,  1.26it/s]
# 100%|██████████| 392/392 [04:54<00:00,  1.33it/s]
# 100%|██████████| 392/392 [05:04<00:00,  1.29it/s]
# 100%|██████████| 392/392 [04:39<00:00,  1.40it/s]
# 100%|██████████| 392/392 [04:45<00:00,  1.37it/s]

# %%
time.sleep(120)

# %%
# repetir o mesmo processamento n vezes
model_anthropic = "claude-3-5-sonnet-20241022" # @param ["gpt-4-turbo-preview", "gpt-4", "gpt-3.5-turbo"]
inclusion_criteria_question =""" Thearticle discusses how to use the relationship be
tween game elements and user types to analyze user  engagement. """
name_ic = "IC2"
df_claude_sonnet_35 = repeat_selection_with_antropic(df = df_claude_sonnet_35,
                                        model_anthropic = model_anthropic,
                                        inclusion_criteria_question = inclusion_criteria_question,
                                        n_interactions = n_interactions,
                                        name_ic = name_ic)
# Out:
# 100%|██████████| 392/392 [04:56<00:00,  1.32it/s]
# 100%|██████████| 392/392 [05:01<00:00,  1.30it/s]
# 100%|██████████| 392/392 [04:50<00:00,  1.35it/s]
# 100%|██████████| 392/392 [04:50<00:00,  1.35it/s]
# 100%|██████████| 392/392 [04:42<00:00,  1.39it/s]

# %% [markdown]
# ### Gravação

# %% [markdown]
# #### claude-3-haiku-20240307

# %%
df_claude_haiku_3.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-haiku-20240307_IC1_0  \
# 0            NaN                              5
# 1            NaN                              5
#
#    claude-3-haiku-20240307_IC1_1  claude-3-haiku-20240307_IC1_2  \
# 0                              5                              5
# 1                              6                              5
#
#    claude-3-haiku-20240307_IC1_3  claude-3-haiku-20240307_IC1_4  \
# 0                              5                              5
# 1                              5                              5
#
#    claude-3-haiku-20240307_IC2_0  claude-3-haiku-20240307_IC2_1  \
# 0                              6                              6
# 1                              5                              5
#
#    claude-3-haiku-20240307_IC2_2  claude-3-haiku-20240307_IC2_3  \
# 0                              6                              6
# 1                              5                              5
#
#    claude-3-haiku-20240307_IC2_4
# 0                              6
# 1                              5

# %%
# grava os resultados
df_claude_haiku_3.to_excel("/data/codigos/dados/resultados/reproducao_resultados_claude_haiku_3_slr2_v2.xlsx", index=False)
df_claude_haiku_3.to_csv("/data/codigos/dados/resultados/reproducao_resultados_claude_haiku_3_slr2_v2.csv", encoding='utf-8', index=False)

# %% [markdown]
# #### claude-3-5-haiku-20241022

# %%
df_claude_haiku_35.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-5-haiku-20241022_IC1_0  \
# 0            NaN                                6
# 1            NaN                                4
#
#    claude-3-5-haiku-20241022_IC1_1  claude-3-5-haiku-20241022_IC1_2  \
# 0                                6                                6
# 1                                4                                4
#
#    claude-3-5-haiku-20241022_IC1_3  claude-3-5-haiku-20241022_IC1_4  \
# 0                                6                                6
# 1                                4                                4
#
#    claude-3-5-haiku-20241022_IC2_0  claude-3-5-haiku-20241022_IC2_1  \
# 0                                5                                5
# 1                                4                                3
#
#    claude-3-5-haiku-20241022_IC2_2  claude-3-5-haiku-20241022_IC2_3  \
# 0                                5                                5
# 1                                4                                4
#
#    claude-3-5-haiku-20241022_IC2_4
# 0                                5
# 1                                4

# %%
# grava os resultados
df_claude_haiku_35.to_excel("/data/codigos/dados/resultados/reproducao_resultados_claude_haiku_35_slr2_v2.xlsx", index=False)
df_claude_haiku_35.to_csv("/data/codigos/dados/resultados/reproducao_resultados_claude_haiku_35_slr2_v2.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### claude-3-5-sonnet-20241022

# %%
df_claude_sonnet_35.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-5-sonnet-20241022_IC1_0  \
# 0            NaN                                 7
# 1            NaN                                 6
#
#    claude-3-5-sonnet-20241022_IC1_1  claude-3-5-sonnet-20241022_IC1_2  \
# 0                                 7                                 7
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC1_3  claude-3-5-sonnet-20241022_IC1_4  \
# 0                                 7                                 7
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC2_0  claude-3-5-sonnet-20241022_IC2_1  \
# 0                                 5                                 5
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC2_2  claude-3-5-sonnet-20241022_IC2_3  \
# 0                                 5                                 5
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC2_4
# 0                                 5
# 1                                 6

# %%
# grava os resultados
df_claude_sonnet_35.to_excel("/data/codigos/dados/resultados/reproducao_resultados_claude_sonnet_35_slr2_v2.xlsx", index=False)
df_claude_sonnet_35.to_csv("/data/codigos/dados/resultados/reproducao_resultados_claude_sonnet_35_slr2_v2.csv", encoding='utf-8', index=False)

# %% [markdown]
# ## Analise dos resultados

# %% [markdown]
# ### Leitura dos resultados processados

# %%
df_claude_haiku_3 = pd.read_csv("/data/codigos/dados/resultados/reproducao_resultados_claude_haiku_3_slr2_v2.csv",encoding='utf-8')
df_claude_haiku_3.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-haiku-20240307_IC1_0  \
# 0            NaN                              5
# 1            NaN                              5
#
#    claude-3-haiku-20240307_IC1_1  claude-3-haiku-20240307_IC1_2  \
# 0                              5                              5
# 1                              6                              5
#
#    claude-3-haiku-20240307_IC1_3  claude-3-haiku-20240307_IC1_4  \
# 0                              5                              5
# 1                              5                              5
#
#    claude-3-haiku-20240307_IC2_0  claude-3-haiku-20240307_IC2_1  \
# 0                              6                              6
# 1                              5                              5
#
#    claude-3-haiku-20240307_IC2_2  claude-3-haiku-20240307_IC2_3  \
# 0                              6                              6
# 1                              5                              5
#
#    claude-3-haiku-20240307_IC2_4
# 0                              6
# 1                              5

# %%
df_claude_haiku_35 = pd.read_csv("/data/codigos/dados/resultados/reproducao_resultados_claude_haiku_35_slr2_v2.csv",encoding='utf-8')
df_claude_haiku_35.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-5-haiku-20241022_IC1_0  \
# 0            NaN                                6
# 1            NaN                                4
#
#    claude-3-5-haiku-20241022_IC1_1  claude-3-5-haiku-20241022_IC1_2  \
# 0                                6                                6
# 1                                4                                4
#
#    claude-3-5-haiku-20241022_IC1_3  claude-3-5-haiku-20241022_IC1_4  \
# 0                                6                                6
# 1                                4                                4
#
#    claude-3-5-haiku-20241022_IC2_0  claude-3-5-haiku-20241022_IC2_1  \
# 0                                5                                5
# 1                                4                                3
#
#    claude-3-5-haiku-20241022_IC2_2  claude-3-5-haiku-20241022_IC2_3  \
# 0                                5                                5
# 1                                4                                4
#
#    claude-3-5-haiku-20241022_IC2_4
# 0                                5
# 1                                4

# %%
df_claude_sonnet_35 = pd.read_csv("/data/codigos/dados/resultados/reproducao_resultados_claude_sonnet_35_slr2_v2.csv",encoding='utf-8')
df_claude_sonnet_35.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  claude-3-5-sonnet-20241022_IC1_0  \
# 0            NaN                                 7
# 1            NaN                                 6
#
#    claude-3-5-sonnet-20241022_IC1_1  claude-3-5-sonnet-20241022_IC1_2  \
# 0                                 7                                 7
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC1_3  claude-3-5-sonnet-20241022_IC1_4  \
# 0                                 7                                 7
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC2_0  claude-3-5-sonnet-20241022_IC2_1  \
# 0                                 5                                 5
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC2_2  claude-3-5-sonnet-20241022_IC2_3  \
# 0                                 5                                 5
# 1                                 6                                 6
#
#    claude-3-5-sonnet-20241022_IC2_4
# 0                                 5
# 1                                 6

# %%
# vamos trazer os dados disponibilizados pelos autores para comparação de performance
df_slr1_autores = pd.read_excel("/data/codigos/dados/SLR2-results-keys.xlsx",engine='openpyxl')
df_slr1_autores.head()
# Out:
#        ID                                              Title  IC1  IC2  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...    6    6
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...    5    5
# 2  slr2_3  Field guide to gamification: Game components a...    7    7
# 3  slr2_4  Gamification of eHealth interventions to incre...    1    2
# 4  slr2_5  The relationship between gender and game dynam...    6    6
#
#   Benchmark Execution time (s)  Total Tokens
# 0         E    1,7697742920136           777
# 1         I   1,26788704199134           889
# 2         I    1,3752188339713          1233
# 3         I   1,54043745799572          1047
# 4         I           1.338598          1175

# %%
df_claude_haiku_3 = pd.merge(left=df_claude_haiku_3, right=df_slr1_autores[["ID","IC1","IC2","Benchmark"]],
                          left_on='ID', right_on='ID',how='left')
df_claude_haiku_3.shape
# Out:
# (392, 23)

# %%
df_claude_haiku_35 = pd.merge(left=df_claude_haiku_35, right=df_slr1_autores[["ID","IC1","IC2","Benchmark"]],
                          left_on='ID', right_on='ID',how='left')
df_claude_haiku_35.shape
# Out:
# (392, 23)

# %%
df_claude_sonnet_35 = pd.merge(left=df_claude_sonnet_35, right=df_slr1_autores[["ID","IC1","IC2","Benchmark"]],
                          left_on='ID', right_on='ID',how='left')
df_claude_sonnet_35.shape
# Out:
# (392, 23)

# %%
print("df_claude_haiku_3: "+str(df_claude_haiku_3.shape))
print("df_claude_haiku_35: "+str(df_claude_haiku_35.shape))
print("df_claude_sonnet_35: "+str(df_claude_sonnet_35.shape))
print("df_slr1_autores: "+str(df_slr1_autores.shape))
# Out:
# df_claude_haiku_3: (392, 23)
# df_claude_haiku_35: (392, 23)
# df_claude_sonnet_35: (392, 23)
# df_slr1_autores: (448, 7)

# %% [markdown]
# ### Geração dos resultados das llms e padronizacao dos campos

# %%
# criando a regra do corte em 5
def convert_benchmark(df,col1):
    df["result_bench"] = np.where(df[col1].str.lower()=="i",1,0)
    return df

# %%
df_claude_haiku_3 = convert_benchmark(df_claude_haiku_3,"Benchmark")

# %%
df_claude_haiku_35 = convert_benchmark(df_claude_haiku_35,"Benchmark")

# %%
df_claude_sonnet_35 = convert_benchmark(df_claude_sonnet_35,"Benchmark")

# %%
def create_result_llm_classic(df,col1,col2,limit1,limit2,col_name):
    """
    Create flag with result for llms
    """
    df["aux_ic1"] = np.where(df[col1]>=limit1,1,0)
    df["aux_ic2"] = np.where(df[col2]>=limit2,1,0)
    df[col_name] = np.where(((df["aux_ic1"]==1) & (df["aux_ic2"]==1)),1,0)
    return df.drop(columns=["aux_ic1","aux_ic2"])

# %%
df_claude_haiku_3.head(1)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  ...  claude-3-haiku-20240307_IC1_4  \
# 0            NaN  ...                              5
#
#    claude-3-haiku-20240307_IC2_0  claude-3-haiku-20240307_IC2_1  \
# 0                              6                              6
#
#    claude-3-haiku-20240307_IC2_2  claude-3-haiku-20240307_IC2_3  \
# 0                              6                              6
#
#    claude-3-haiku-20240307_IC2_4  IC1  IC2  Benchmark  result_bench
# 0                              6    6    6          E             0
#
# [1 rows x 24 columns]

# %%
# Cria a resposta final para cada iteração
def calculate_select_result_llm(n_interactions, model_gpt, df):
    name_ic1 = "IC1"
    name_ic2 = "IC2"
    for i in range(n_interactions):
        coluna_aux1 = model_gpt+"_"+name_ic1+"_"+str(i)
        coluna_aux2 = model_gpt+"_"+name_ic2+"_"+str(i)
        col_name = model_gpt+"_"+str(i)
        df = create_result_llm_classic(df=df,
                                        col1=coluna_aux1,
                                        col2=coluna_aux2,
                                        limit1=5,
                                        limit2=5,
                                        col_name=col_name)
    return df

# %%
n_interactions = 5

# %%
model_gpt = "claude-3-haiku-20240307"
df_claude_haiku_3 = calculate_select_result_llm(n_interactions=n_interactions, model_gpt=model_gpt, df=df_claude_haiku_3)

# %%
df_claude_haiku_3.head(2)
# Out:
#        ID                                              title  \
# 0  slr2_1  Redesigning the bartle test of gamer psycholog...
# 1  slr2_2  Towards adaptive gamification: A synthesis of ...
#
#                                             abstract  \
# 0  According to the literature review, to impleme...
# 1  Adaptive gamification is an emerging and fast-...
#
#                                             keywords sucesso_fracasso_resumo  \
# 0  Bartle Test, Video Games, Gamification, Motiva...                 sucesso
# 1  Adaptive gamification, structured literature r...                 sucesso
#
#   sucesso_fracasso_palavras segunda_coleta              obs flag_pdfs  \
# 0                   sucesso            não  não estruturado       sim
# 1                   sucesso            não  não estruturado       sim
#
#   tentar_via_vpn  ...  claude-3-haiku-20240307_IC2_4  IC1  IC2  Benchmark  \
# 0            NaN  ...                              6    6    6          E
# 1            NaN  ...                              5    5    5          I
#
#    result_bench  claude-3-haiku-20240307_0  claude-3-haiku-20240307_1  \
# 0             0                          1                          1
# 1             1                          1                          1
#
#    claude-3-haiku-20240307_2  claude-3-haiku-20240307_3  \
# 0                          1                          1
# 1                          1                          1
#
#    claude-3-haiku-20240307_4
# 0                          1
# 1                          1
#
# [2 rows x 29 columns]

# %%
model_gpt = "claude-3-5-haiku-20241022"
df_claude_haiku_35 = calculate_select_result_llm(n_interactions=n_interactions, model_gpt=model_gpt, df=df_claude_haiku_35)

# %%
model_gpt = "claude-3-5-sonnet-20241022"
df_claude_sonnet_35 = calculate_select_result_llm(n_interactions=n_interactions, model_gpt=model_gpt, df=df_claude_sonnet_35)

# %% [markdown]
# ### Analises de performance

# %%
def calculate_accuracy(n_interactions, model_gpt, df, col_benchmark):
    """
    Calcula a acurácia para cada iteração e armazena os resultados em um dataframe.
    
    Parâmetros:
    n_interactions (int): Número de interações.
    model_gpt (str): Nome do modelo GPT.
    df (pd.DataFrame): DataFrame contendo os dados.
    col_benchmark (str): Nome da coluna de benchmark.
    
    Retorna:
    pd.DataFrame: DataFrame com as colunas 'Model_Iteration' e 'Accuracy'.
    """
    accuracy_results = []

    for i in range(n_interactions):
        col_name = model_gpt + "_" + str(i)
        accuracy = accuracy_score(df[col_benchmark], df[col_name])
        accuracy_results.append({'Model_Iteration': col_name, 'Accuracy': accuracy})

    return pd.DataFrame(accuracy_results)

# %%
n_interactions = 5

# %%
model_gpt = "claude-3-haiku-20240307"
df_result_claude_haiku_3 = calculate_accuracy(n_interactions=n_interactions,
                                    model_gpt=model_gpt,
                                    df=df_claude_haiku_3, 
                                    col_benchmark='result_bench')
df_result_claude_haiku_3
# Out:
#              Model_Iteration  Accuracy
# 0  claude-3-haiku-20240307_0  0.806122
# 1  claude-3-haiku-20240307_1  0.808673
# 2  claude-3-haiku-20240307_2  0.806122
# 3  claude-3-haiku-20240307_3  0.808673
# 4  claude-3-haiku-20240307_4  0.806122

# %%
model_gpt = "claude-3-5-haiku-20241022"
df_result_claude_haiku_35 = calculate_accuracy(n_interactions=n_interactions,
                                    model_gpt=model_gpt,
                                    df=df_claude_haiku_35, 
                                    col_benchmark='result_bench')
df_result_claude_haiku_35
# Out:
#                Model_Iteration  Accuracy
# 0  claude-3-5-haiku-20241022_0  0.798469
# 1  claude-3-5-haiku-20241022_1  0.798469
# 2  claude-3-5-haiku-20241022_2  0.801020
# 3  claude-3-5-haiku-20241022_3  0.801020
# 4  claude-3-5-haiku-20241022_4  0.798469

# %%
model_gpt = "claude-3-5-sonnet-20241022"
df_result_claude_sonnet_35 = calculate_accuracy(n_interactions=n_interactions,
                                    model_gpt=model_gpt,
                                    df=df_claude_sonnet_35, 
                                    col_benchmark='result_bench')
df_result_claude_sonnet_35
# Out:
#                 Model_Iteration  Accuracy
# 0  claude-3-5-sonnet-20241022_0  0.836735
# 1  claude-3-5-sonnet-20241022_1  0.834184
# 2  claude-3-5-sonnet-20241022_2  0.834184
# 3  claude-3-5-sonnet-20241022_3  0.834184
# 4  claude-3-5-sonnet-20241022_4  0.834184

# %%
def graph_scatter_plot(df,col_values,col_name_models,title_graph,xlabel,ylabel,ylim_flag,ylim):
    # Supondo que df seja o dataframe com as colunas "Model_Iteration" e "Accuracy"
    # Calcular a média e o desvio padrão da acurácia
    mean_accuracy = df[col_values].mean()
    std_accuracy = df[col_values].std()

    # Configurar o tamanho da figura
    plt.figure(figsize=(12, 6))

    # Criar o scatterplot
    plt.scatter(df[col_name_models], df[col_values], color='royalblue', label='Accuracy')

    # Adicionar linhas horizontais para a média e os limites inferior e superior
    plt.axhline(y=mean_accuracy, color='darkblue', linestyle='-', label='Mean Accuracy')
    plt.axhline(y=mean_accuracy - std_accuracy, color='cornflowerblue', linestyle='--', label='Mean - Std Dev')
    plt.axhline(y=mean_accuracy + std_accuracy, color='cornflowerblue', linestyle='--', label='Mean + Std Dev')

    # Adicionar título e nomes nos eixos
    plt.title(title_graph)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    # Adicionar legenda
    plt.legend()

    # limite
    if ylim_flag:
        plt.ylim(ylim)

    # Rotacionar os rótulos do eixo x para melhor visualização
    plt.xticks(rotation=45)

    # Exibir o gráfico
    plt.tight_layout()
    
    # Remover bordas desnecessárias
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.show()

# %%
graph_scatter_plot(df = df_result_claude_haiku_3,
                    col_values = "Accuracy",
                    col_name_models = "Model_Iteration",
                    title_graph = "Comparison of results for the same llm model - claude-3-haiku-20240307",
                    xlabel = "model iteration",
                    ylabel = "Accuracy",
                    ylim_flag=False,
                    ylim=[0.50,0.8])

# %%
graph_scatter_plot(df = df_result_claude_haiku_35,
                    col_values = "Accuracy",
                    col_name_models = "Model_Iteration",
                    title_graph = "Comparison of results for the same llm model - claude-3-5-haiku-20241022",
                    xlabel = "model iteration",
                    ylabel = "Accuracy",
                    ylim_flag=False,
                    ylim=[0.50,0.8])

# %%
graph_scatter_plot(df = df_result_claude_sonnet_35,
                    col_values = "Accuracy",
                    col_name_models = "Model_Iteration",
                    title_graph = "Comparison of results for the same llm model - claude-3-5-sonnet-20241022",
                    xlabel = "model iteration",
                    ylabel = "Accuracy",
                    ylim_flag=False,
                    ylim=[0.50,0.8])

# %% [markdown]
# Nota-se que para modelos mais avançados a variabilidade é menor, indicando estabilização mais rápida.

# %%
### Grava os resultados finais
df_result_claude_haiku_3.to_excel("/data/codigos/dados/resultados/reproducao_acuracia_claude_haiku_3_final_slr2_v2.xlsx", index=False)
df_result_claude_haiku_3.to_csv("/data/codigos/dados/resultados/reproducao_acuracia_claude_haiku_3_final_slr2_v2.csv", encoding='utf-8', index=False)

df_result_claude_haiku_35.to_excel("/data/codigos/dados/resultados/reproducao_acuracia_claude_haiku_35_slr2_v2.xlsx", index=False)
df_result_claude_haiku_35.to_csv("/data/codigos/dados/resultados/reproducao_acuracia_claude_haiku_35_slr2_v2.csv", encoding='utf-8', index=False)

df_result_claude_sonnet_35.to_excel("/data/codigos/dados/resultados/reproducao_acuracia_claude_sonnet_35_slr2_v2.xlsx", index=False)
df_result_claude_sonnet_35.to_csv("/data/codigos/dados/resultados/reproducao_acuracia_claude_sonnet_35_slr2_v2.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### Comparativo geral

# %%
df_result_claude_haiku_3["iteration"] = df_result_claude_haiku_3["Model_Iteration"].str.extract(r'_(\d+)$')[0].astype(int)
df_result_claude_haiku_3["model"] = "claude-3-haiku-20240307"

df_result_claude_haiku_35["iteration"] = df_result_claude_haiku_35["Model_Iteration"].str.extract(r'_(\d+)$')[0].astype(int)
df_result_claude_haiku_35["model"] = "claude-3-5-haiku-20241022"

df_result_claude_sonnet_35["iteration"] = df_result_claude_sonnet_35["Model_Iteration"].str.extract(r'_(\d+)$')[0].astype(int)
df_result_claude_sonnet_35["model"] = "claude-3-5-sonnet-20241022"

# %%
# concatena os dataframes
df_results = pd.concat([df_result_claude_haiku_3, 
                        df_result_claude_haiku_35, 
                        df_result_claude_sonnet_35], ignore_index=True)
df_results.head(2)
# Out:
#              Model_Iteration  Accuracy  iteration                    model
# 0  claude-3-haiku-20240307_0  0.806122          0  claude-3-haiku-20240307
# 1  claude-3-haiku-20240307_1  0.808673          1  claude-3-haiku-20240307

# %%
plt.figure(figsize=(10, 6))
for model_name, group in df_results.groupby("model"):
    plt.plot(group["iteration"], group["Accuracy"], marker='o', label=model_name)

plt.title("Accuracy by Iteration for Each LLM Model - anthropic")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.legend(title="Model", loc='lower center', bbox_to_anchor=(0.5, -0.25), ncol=3)
plt.show()
